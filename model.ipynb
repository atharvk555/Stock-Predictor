# %%
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from sklearn.metrics import accuracy_score

# %%
from datetime import datetime
end=datetime.now()
start=datetime(end.year-20,end.month,end.day)

# %%
stock = "TATAMTRDVR.NS"
tata_data = yf.download(stock, start, end)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tata_data.head()
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2008-11-05  30.049999  53.799999  30.049999  47.619999  41.277798   35770
# 2008-11-06  42.000000  47.970001  42.000000  43.860001  38.018574     220
# 2008-11-07  45.799999  52.340000  36.009998  48.200001  41.780552    1250
# 2008-11-10  55.000000  57.200001  42.099998  47.680000  41.329807    2505
# 2008-11-11  53.400002  56.000000  45.110001  51.720001  44.831749     450

# %%
tata_data.shape
# Out:
# (3891, 6)

# %%
tata_data.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  3891.000000  3891.000000  3891.000000  3891.000000  3891.000000
# mean    201.148684   204.229463   197.671976   200.785657   196.675981
# std     133.689528   135.173219   131.865426   133.497825   134.298683
# min      21.600000    22.670000    21.600000    22.670000    19.650732
# 25%     100.000000   101.800003    98.459999    99.885002    94.670769
# 50%     170.500000   173.199997   167.500000   170.149994   164.343369
# 75%     265.000000   268.375000   260.825012   264.375000   261.456451
# max     796.000000   804.299988   782.950012   793.000000   793.000000
#
#              Volume
# count  3.891000e+03
# mean   2.986563e+06
# std    3.580621e+06
# min    0.000000e+00
# 25%    1.295016e+06
# 50%    2.119862e+06
# 75%    3.522265e+06
# max    6.839672e+07

# %%
tata_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3891 entries, 2008-11-05 to 2024-08-21
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       3891 non-null   float64
#  1   High       3891 non-null   float64
#  2   Low        3891 non-null   float64
#  3   Close      3891 non-null   float64
#  4   Adj Close  3891 non-null   float64
#  5   Volume     3891 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 212.8 KB

# %%
tata_data.isna().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
plt.figure(figsize = (15,5))
tata_data['Adj Close'].plot()
plt.xlabel("years")
plt.ylabel("Adj Close")
plt.title("Closing price of Tata Motors data")
# Out:
# Text(0.5, 1.0, 'Closing price of Tata Motors data')

# %%
def plot_graph(figsize, values, column_name):
    plt.figure()
    values.plot(figsize = figsize)
    plt.xlabel("years")
    plt.ylabel(column_name)
    plt.title(f"{column_name} of Tata Motors data")

# %%
tata_data.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
for column in tata_data.columns:
    plot_graph((15,5),tata_data[column], column)

# %%
for i in range(2014,2025):
    print(i,list(tata_data.index.year).count(i))
# Out:
# 2014 244
# 2015 246
# 2016 246
# 2017 248
# 2018 246
# 2019 243
# 2020 251
# 2021 248
# 2022 248
# 2023 245
# 2024 156

# %%
tata_data['MA_for_240_days'] = tata_data['Adj Close'].rolling(240).mean()

# %%
tata_data['MA_for_240_days'][0:240].tail()
# Out:
# Date
# 2009-10-26         NaN
# 2009-10-27         NaN
# 2009-10-28         NaN
# 2009-10-29         NaN
# 2009-10-30    44.44726
# Name: MA_for_240_days, dtype: float64

# %%
plot_graph((15,5), tata_data['MA_for_240_days'], 'MA_for_240_days')

# %%
plot_graph((15,5),tata_data[['Adj Close','MA_for_240_days']], 'MA_for_240_days')

# %%
tata_data['MA_for_100_days'] = tata_data['Adj Close'].rolling(100).mean()
plot_graph((15,5), tata_data[['Adj Close','MA_for_100_days']], 'MA_for_100_days')

# %%
tata_data['percentage_change_cp'] = tata_data['Adj Close'].pct_change()
tata_data[['Adj Close','percentage_change_cp']].head()
# Out:
#             Adj Close  percentage_change_cp
# Date
# 2008-11-05  41.277798                   NaN
# 2008-11-06  38.018574             -0.078958
# 2008-11-07  41.780552              0.098951
# 2008-11-10  41.329807             -0.010788
# 2008-11-11  44.831749              0.084732

# %%
plot_graph((15,5), tata_data['percentage_change_cp'], 'percentage_change')

# %%
Adj_close_price = tata_data[['Adj Close']]

# %%
max(Adj_close_price.values),min(Adj_close_price.values)
# Out:
# (array([793.]), array([19.65073204]))

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(Adj_close_price)
scaled_data
# Out:
# array([[0.02796546],
#        [0.02375103],
#        [0.02861556],
#        ...,
#        [0.94316926],
#        [0.94342789],
#        [0.94038919]])

# %%
len(scaled_data)
# Out:
# 3891

# %%
x_data = []
y_data = []

for i in range(100, len(scaled_data)):
    x_data.append(scaled_data[i-100:i])
    y_data.append(scaled_data[i])
    

x_data, y_data = np.array(x_data), np.array(y_data)

# %%
x_data[0],y_data[0]
# Out:
# (array([[0.02796546],
#         [0.02375103],
#         [0.02861556],
#         [0.02803271],
#         [0.03256099],
#         [0.03699959],
#         [0.03699959],
#         [0.02529782],
#         [0.01566963],
#         [0.01099564],
#         [0.01099564],
#         [0.0099084 ],
#         [0.0099084 ],
#         [0.0099084 ],
#         [0.01135431],
#         [0.01135431],
#         [0.0082159 ],
#         [0.01135431],
#         [0.01135431],
#         [0.01135431],
#         [0.00776756],
#         [0.00776756],
#         [0.00776756],
#         [0.00776756],
#         [0.00776756],
#         [0.0110741 ],
#         [0.0110741 ],
#         [0.00765547],
#         [0.00608627],
#         [0.00608627],
#         [0.00608627],
#         [0.00608627],
#         [0.00608627],
#         [0.00608627],
#         [0.00777877],
#         [0.00777877],
#         [0.00777877],
#         [0.00470761],
#         [0.00470761],
#         [0.00470761],
#         [0.00459553],
#         [0.00459553],
#         [0.00459553],
#         [0.00215205],
#         [0.00215205],
#         [0.00215205],
#         [0.00239864],
#         [0.        ],
#         [0.00254435],
#         [0.0053465 ],
#         [0.00842887],
#         [0.01180266],
#         [0.01366329],
#         [0.01538941],
#         [0.01538941],
#         [0.01538941],
#         [0.01538941],
#         [0.01538941],
#         [0.01334944],
#         [0.01334944],
#         [0.01334944],
#         [0.01334944],
#         [0.01334944],
#         [0.01334944],
#         [0.01334944],
#         [0.01334944],
#         [0.01334944],
#         [0.01334944],
#         [0.01334944],
#         [0.01334944],
#         [0.01334944],
#         [0.01334944],
#         [0.01157848],
#         [0.01000928],
#         [0.01000928],
#         [0.01000928],
#         [0.01000928],
#         [0.01000928],
#         [0.01000928],
#         [0.01000928],
#         [0.01000928],
#         [0.01000928],
#         [0.01000928],
#         [0.01000928],
#         [0.01178024],
#         [0.01178024],
#         [0.01269935],
#         [0.01090597],
#         [0.01269935],
#         [0.0138202 ],
#         [0.01387625],
#         [0.01202683],
#         [0.01202683],
#         [0.01202683],
#         [0.01202683],
#         [0.01202683],
#         [0.01202683],
#         [0.01202683],
#         [0.01202683],
#         [0.01202683]]),
#  array([0.01389866]))

# %%
x_train,x_test,y_train,y_test=train_test_split(x_data,y_data,test_size=0.3)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (2653, 100, 1)
# (2653, 1)
# (1138, 100, 1)
# (1138, 1)

# %%
model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(LSTM(64,return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))
# Out:
# a:\stockpred\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.fit(x_train, y_train, batch_size=1, epochs = 2)
# Out:
# Epoch 1/2
# 2653/2653 ━━━━━━━━━━━━━━━━━━━━ 43s 16ms/step - loss: 0.0018
# Epoch 2/2
# 2653/2653 ━━━━━━━━━━━━━━━━━━━━ 42s 16ms/step - loss: 4.4054e-04

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100, 128)       │        66,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 25)             │         1,625 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 352,859 (1.35 MB)
#  Trainable params: 117,619 (459.45 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 235,240 (918.91 KB)

# %%
predictions = model.predict(x_test)
# Out:
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step

# %%
predictions
# Out:
# array([[0.34962717],
#        [0.05305312],
#        [0.05634271],
#        ...,
#        [0.33324617],
#        [0.17936298],
#        [0.26800033]], dtype=float32)

# %%
inv_predictions = scaler.inverse_transform(predictions)
inv_predictions
# Out:
# array([[290.03464 ],
#        [ 60.679325],
#        [ 63.223324],
#        ...,
#        [277.36642 ],
#        [158.36096 ],
#        [226.9086  ]], dtype=float32)

# %%
inv_y_test = scaler.inverse_transform(y_test)
inv_y_test
# Out:
# array([[300.2605896 ],
#        [ 39.71022415],
#        [ 47.48392868],
#        ...,
#        [279.73205566],
#        [143.68553162],
#        [219.74313354]])

# %%
rmse = np.sqrt(np.mean( (inv_predictions - inv_y_test)**2))

# %%
rmse
# Out:
# 15.765494414360044

# %%
splitting_len = int(len(x_data)*0.7)

# %%
ploting_data = pd.DataFrame(
 {
  'original_test_data': inv_y_test.reshape(-1),
    'predictions': inv_predictions.reshape(-1)
 } ,
    index = tata_data.index[splitting_len+100:]
)
ploting_data.head()
# Out:
#             original_test_data  predictions
# Date
# 2020-01-15          300.260590   290.034637
# 2020-01-16           39.710224    60.679325
# 2020-01-17           47.483929    63.223324
# 2020-01-20          165.504456   174.805252
# 2020-01-21           84.953163    97.738289

# %%
plot_graph((15,6), ploting_data, 'test data')

# %%
plot_graph((15,6), pd.concat([Adj_close_price[:splitting_len+100],ploting_data], axis=0), 'whole data')

# %%
model.save("Latest_stock_price_model.keras")
